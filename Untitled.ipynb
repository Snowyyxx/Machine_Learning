# %%
from sklearn.datasets import load_digits

# %%
type(load_digits)
# Out:
# function

# %%
x,y = load_digits(as_frame=True,return_X_y=True)

# %%
type(x)
import matplotlib.pyplot as plt

# %%
img1 = x[7:8]
img1 = img1.to_numpy()
# pltmatshow(img1)
img1 = img1.reshape(8,8)
img1.shape
# Out:
# (8, 8)

# %%
plt.imshow(img1)

# %%
y.head(11)
import numpy as np
import pandas as pd

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in /Users/aditya/opt/anaconda3/lib/python3.8/site-packages (8.0.1)

# %%
from PIL import Image
image = Image.open("img.jpg")
img = np.asarray(image)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (4608, 3456, 3)

# %%
img = img.flatten()

# %%
img.shape
# Out:
# (47775744,)

# %%
type(img)
# Out:
# numpy.ndarray
